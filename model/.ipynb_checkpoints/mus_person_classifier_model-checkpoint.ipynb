# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/eminem.jpg')
img.shape
# Out:
# (320, 332, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (320, 332)

# %%
plt.imshow(gray)

# %%
gray
# Out:
# array([[ 44,  44,  44, ..., 122, 122, 122],
#        [ 44,  44,  44, ..., 122, 122, 122],
#        [ 44,  44,  44, ..., 122, 122, 122],
#        ...,
#        [204, 204, 204, ...,  17,  14,  11],
#        [204, 204, 204, ...,  16,  17,  17],
#        [204, 204, 204, ...,   9,  21,  32]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[92, 59, 97, 97]])

# %%
(x, y, w, h) = faces[0]
x, y, w, h
# Out:
# (92, 59, 97, 97)

# %%
face_img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/eminem.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = './dataset/'
path_to_cr_data = './dataset/cropped/'

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)
        
img_dirs
# Out:
# ['./dataset/chuck_berry',
#  './dataset/eminem',
#  './dataset/justin_bieber',
#  './dataset/madonna',
#  './dataset/whitney_houston']

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
img_dirs
# Out:
# ['./dataset/chuck_berry',
#  './dataset/eminem',
#  './dataset/justin_bieber',
#  './dataset/madonna',
#  './dataset/whitney_houston']

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print(f'generating cropped images in folder: {cropped_folder}')
            
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + '/' + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
            
print('DONE!')
# Out:
# chuck_berry
# generating cropped images in folder: ./dataset/cropped/chuck_berry
# eminem
# generating cropped images in folder: ./dataset/cropped/eminem
# justin_bieber
# generating cropped images in folder: ./dataset/cropped/justin_bieber
# madonna
# generating cropped images in folder: ./dataset/cropped/madonna
# whitney_houston
# generating cropped images in folder: ./dataset/cropped/whitney_houston
# DONE!

# %%
import pywt

def w2d(img, mode='haar', level=1):
    imArray = img
    #datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor(imArray, cv2.COLOR_RGB2GRAY)
    #convert to float
    imArray = np.float32(imArray)
    imArray /= 255
    #compute coefficients
    coeffs = pywt.wavedec2(imArray, mode, level=level)
    
    #process_coefficients
    coeffs_H = list(coeffs)
    coeffs_H[0] *= 0
    
    #reconstruction
    imArray_H = pywt.waverec2(coeffs_H, mode)
    imArray_H *= 255
    imArray_H = np.uint8(imArray_H)
    
    return imArray_H

# %%
im_har = w2d(cropped_image, 'db1', 5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'chuck_berry': ['./dataset/cropped/chuck_berry/chuck_berry1.png',
#   './dataset/cropped/chuck_berry/chuck_berry2.png',
#   './dataset/cropped/chuck_berry/chuck_berry3.png',
#   './dataset/cropped/chuck_berry/chuck_berry4.png',
#   './dataset/cropped/chuck_berry/chuck_berry5.png',
#   './dataset/cropped/chuck_berry/chuck_berry6.png',
#   './dataset/cropped/chuck_berry/chuck_berry7.png',
#   './dataset/cropped/chuck_berry/chuck_berry8.png',
#   './dataset/cropped/chuck_berry/chuck_berry9.png',
#   './dataset/cropped/chuck_berry/chuck_berry10.png',
#   './dataset/cropped/chuck_berry/chuck_berry11.png',
#   './dataset/cropped/chuck_berry/chuck_berry12.png',
#   './dataset/cropped/chuck_berry/chuck_berry13.png',
#   './dataset/cropped/chuck_berry/chuck_berry14.png',
#   './dataset/cropped/chuck_berry/chuck_berry15.png',
#   './dataset/cropped/chuck_berry/chuck_berry16.png',
#   './dataset/cropped/chuck_berry/chuck_berry17.png',
#   './dataset/cropped/chuck_berry/chuck_berry18.png',
#   './dataset/cropped/chuck_berry/chuck_berry19.png',
#   './dataset/cropped/chuck_berry/chuck_berry20.png',
#   './dataset/cropped/chuck_berry/chuck_berry21.png',
#   './dataset/cropped/chuck_berry/chuck_berry22.png',
#   './dataset/cropped/chuck_berry/chuck_berry23.png',
#   './dataset/cropped/chuck_berry/chuck_berry24.png',
#   './dataset/cropped/chuck_berry/chuck_berry25.png',
#   './dataset/cropped/chuck_berry/chuck_berry26.png'],
#  'eminem': ['./dataset/cropped/eminem/eminem1.png',
#   './dataset/cropped/eminem/eminem2.png',
#   './dataset/cropped/eminem/eminem3.png',
#   './dataset/cropped/eminem/eminem4.png',
#   './dataset/cropped/eminem/eminem5.png',
#   './dataset/cropped/eminem/eminem6.png',
#   './dataset/cropped/eminem/eminem7.png',
#   './dataset/cropped/eminem/eminem8.png',
#   './dataset/cropped/eminem/eminem9.png',
#   './dataset/cropped/eminem/eminem10.png',
#   './dataset/cropped/eminem/eminem11.png',
#   './dataset/cropped/eminem/eminem12.png',
#   './dataset/cropped/eminem/eminem13.png',
#   './dataset/cropped/eminem/eminem14.png',
#   './dataset/cropped/eminem/eminem15.png',
#   './dataset/cropped/eminem/eminem16.png',
#   './dataset/cropped/eminem/eminem17.png',
#   './dataset/cropped/eminem/eminem18.png',
#   './dataset/cropped/eminem/eminem19.png',
#   './dataset/cropped/eminem/eminem20.png',
#   './dataset/cropped/eminem/eminem21.png',
#   './dataset/cropped/eminem/eminem22.png',
#   './dataset/cropped/eminem/eminem23.png',
#   './dataset/cropped/eminem/eminem24.png',
#   './dataset/cropped/eminem/eminem25.png',
#   './dataset/cropped/eminem/eminem26.png',
#   './dataset/cropped/eminem/eminem27.png',
#   './dataset/cropped/eminem/eminem28.png',
#   './dataset/cropped/eminem/eminem29.png',
#   './dataset/cropped/eminem/eminem30.png',
#   './dataset/cropped/eminem/eminem31.png',
#   './dataset/cropped/eminem/eminem32.png',
#   './dataset/cropped/eminem/eminem33.png',
#   './dataset/cropped/eminem/eminem34.png',
#   './dataset/cropped/eminem/eminem35.png',
#   './dataset/cropped/eminem/eminem36.png',
#   './dataset/cropped/eminem/eminem37.png',
#   './dataset/cropped/eminem/eminem38.png',
#   './dataset/cropped/eminem/eminem39.png',
#   './dataset/cropped/eminem/eminem40.png',
#   './dataset/cropped/eminem/eminem41.png',
#   './dataset/cropped/eminem/eminem42.png',
#   './dataset/cropped/eminem/eminem43.png',
#   './dataset/cropped/eminem/eminem44.png',
#   './dataset/cropped/eminem/eminem45.png',
#   './dataset/cropped/eminem/eminem46.png',
#   './dataset/cropped/eminem/eminem47.png'],
#  'justin_bieber': ['./dataset/cropped/justin_bieber/justin_bieber1.png',
#   './dataset/cropped/justin_bieber/justin_bieber2.png',
#   './dataset/cropped/justin_bieber/justin_bieber3.png',
#   './dataset/cropped/justin_bieber/justin_bieber4.png',
#   './dataset/cropped/justin_bieber/justin_bieber5.png',
#   './dataset/cropped/justin_bieber/justin_bieber6.png',
#   './dataset/cropped/justin_bieber/justin_bieber7.png',
#   './dataset/cropped/justin_bieber/justin_bieber8.png',
#   './dataset/cropped/justin_bieber/justin_bieber9.png',
#   './dataset/cropped/justin_bieber/justin_bieber10.png',
#   './dataset/cropped/justin_bieber/justin_bieber11.png',
#   './dataset/cropped/justin_bieber/justin_bieber12.png',
#   './dataset/cropped/justin_bieber/justin_bieber13.png',
#   './dataset/cropped/justin_bieber/justin_bieber14.png',
#   './dataset/cropped/justin_bieber/justin_bieber15.png',
#   './dataset/cropped/justin_bieber/justin_bieber16.png',
#   './dataset/cropped/justin_bieber/justin_bieber17.png',
#   './dataset/cropped/justin_bieber/justin_bieber18.png',
#   './dataset/cropped/justin_bieber/justin_bieber19.png',
#   './dataset/cropped/justin_bieber/justin_bieber20.png',
#   './dataset/cropped/justin_bieber/justin_bieber21.png',
#   './dataset/cropped/justin_bieber/justin_bieber22.png',
#   './dataset/cropped/justin_bieber/justin_bieber23.png',
#   './dataset/cropped/justin_bieber/justin_bieber24.png',
#   './dataset/cropped/justin_bieber/justin_bieber25.png',
#   './dataset/cropped/justin_bieber/justin_bieber26.png',
#   './dataset/cropped/justin_bieber/justin_bieber27.png',
#   './dataset/cropped/justin_bieber/justin_bieber28.png',
#   './dataset/cropped/justin_bieber/justin_bieber29.png',
#   './dataset/cropped/justin_bieber/justin_bieber30.png',
#   './dataset/cropped/justin_bieber/justin_bieber31.png',
#   './dataset/cropped/justin_bieber/justin_bieber32.png',
#   './dataset/cropped/justin_bieber/justin_bieber33.png',
#   './dataset/cropped/justin_bieber/justin_bieber34.png',
#   './dataset/cropped/justin_bieber/justin_bieber35.png'],
#  'madonna': ['./dataset/cropped/madonna/madonna1.png',
#   './dataset/cropped/madonna/madonna2.png',
#   './dataset/cropped/madonna/madonna3.png',
#   './dataset/cropped/madonna/madonna4.png',
#   './dataset/cropped/madonna/madonna5.png',
#   './dataset/cropped/madonna/madonna6.png',
#   './dataset/cropped/madonna/madonna7.png',
#   './dataset/cropped/madonna/madonna8.png',
#   './dataset/cropped/madonna/madonna9.png',
#   './dataset/cropped/madonna/madonna10.png',
#   './dataset/cropped/madonna/madonna11.png',
#   './dataset/cropped/madonna/madonna12.png',
#   './dataset/cropped/madonna/madonna13.png',
#   './dataset/cropped/madonna/madonna14.png',
#   './dataset/cropped/madonna/madonna15.png',
#   './dataset/cropped/madonna/madonna16.png',
#   './dataset/cropped/madonna/madonna17.png',
#   './dataset/cropped/madonna/madonna18.png',
#   './dataset/cropped/madonna/madonna19.png',
#   './dataset/cropped/madonna/madonna20.png',
#   './dataset/cropped/madonna/madonna21.png',
#   './dataset/cropped/madonna/madonna22.png',
#   './dataset/cropped/madonna/madonna23.png',
#   './dataset/cropped/madonna/madonna24.png',
#   './dataset/cropped/madonna/madonna25.png',
#   './dataset/cropped/madonna/madonna26.png',
#   './dataset/cropped/madonna/madonna27.png',
#   './dataset/cropped/madonna/madonna28.png',
#   './dataset/cropped/madonna/madonna29.png',
#   './dataset/cropped/madonna/madonna30.png',
#   './dataset/cropped/madonna/madonna31.png',
#   './dataset/cropped/madonna/madonna32.png',
#   './dataset/cropped/madonna/madonna33.png',
#   './dataset/cropped/madonna/madonna34.png',
#   './dataset/cropped/madonna/madonna35.png',
#   './dataset/cropped/madonna/madonna36.png',
#   './dataset/cropped/madonna/madonna37.png',
#   './dataset/cropped/madonna/madonna38.png',
#   './dataset/cropped/madonna/madonna39.png',
#   './dataset/cropped/madonna/madonna40.png',
#   './dataset/cropped/madonna/madonna41.png',
#   './dataset/cropped/madonna/madonna42.png',
#   './dataset/cropped/madonna/madonna43.png',
#   './dataset/cropped/madonna/madonna44.png',
#   './dataset/cropped/madonna/madonna45.png',
#   './dataset/cropped/madonna/madonna46.png',
#   './dataset/cropped/madonna/madonna47.png',
#   './dataset/cropped/madonna/madonna48.png',
#   './dataset/cropped/madonna/madonna49.png',
#   './dataset/cropped/madonna/madonna50.png',
#   './dataset/cropped/madonna/madonna51.png',
#   './dataset/cropped/madonna/madonna52.png',
#   './dataset/cropped/madonna/madonna53.png',
#   './dataset/cropped/madonna/madonna54.png',
#   './dataset/cropped/madonna/madonna55.png',
#   './dataset/cropped/madonna/madonna56.png',
#   './dataset/cropped/madonna/madonna57.png'],
#  'whitney_houston': ['./dataset/cropped/whitney_houston/whitney_houston1.png',
#   './dataset/cropped/whitney_houston/whitney_houston2.png',
#   './dataset/cropped/whitney_houston/whitney_houston3.png',
#   './dataset/cropped/whitney_houston/whitney_houston4.png',
#   './dataset/cropped/whitney_houston/whitney_houston5.png',
#   './dataset/cropped/whitney_houston/whitney_houston6.png',
#   './dataset/cropped/whitney_houston/whitney_houston7.png',
#   './dataset/cropped/whitney_houston/whitney_houston8.png',
#   './dataset/cropped/whitney_houston/whitney_houston9.png',
#   './dataset/cropped/whitney_houston/whitney_houston10.png',
#   './dataset/cropped/whitney_houston/whitney_houston11.png',
#   './dataset/cropped/whitney_houston/whitney_houston12.png',
#   './dataset/cropped/whitney_houston/whitney_houston13.png',
#   './dataset/cropped/whitney_houston/whitney_houston14.png',
#   './dataset/cropped/whitney_houston/whitney_houston15.png',
#   './dataset/cropped/whitney_houston/whitney_houston16.png',
#   './dataset/cropped/whitney_houston/whitney_houston17.png',
#   './dataset/cropped/whitney_houston/whitney_houston18.png',
#   './dataset/cropped/whitney_houston/whitney_houston19.png',
#   './dataset/cropped/whitney_houston/whitney_houston20.png',
#   './dataset/cropped/whitney_houston/whitney_houston21.png',
#   './dataset/cropped/whitney_houston/whitney_houston22.png',
#   './dataset/cropped/whitney_houston/whitney_houston23.png',
#   './dataset/cropped/whitney_houston/whitney_houston24.png',
#   './dataset/cropped/whitney_houston/whitney_houston25.png',
#   './dataset/cropped/whitney_houston/whitney_houston26.png',
#   './dataset/cropped/whitney_houston/whitney_houston27.png',
#   './dataset/cropped/whitney_houston/whitney_houston28.png',
#   './dataset/cropped/whitney_houston/whitney_houston29.png',
#   './dataset/cropped/whitney_houston/whitney_houston30.png',
#   './dataset/cropped/whitney_houston/whitney_houston31.png',
#   './dataset/cropped/whitney_houston/whitney_houston32.png',
#   './dataset/cropped/whitney_houston/whitney_houston33.png',
#   './dataset/cropped/whitney_houston/whitney_houston34.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'chuck_berry': 0,
#  'eminem': 1,
#  'justin_bieber': 2,
#  'madonna': 3,
#  'whitney_houston': 4}

# %%
X = []
y = []

for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img, 'db1', 5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3, 1), scalled_img_har.reshape(32*32, 1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X), len(y)
# Out:
# (4096, 190)

# %%
32**2*3 + 32**2
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X), 4096).astype(float)
X.shape
# Out:
# (190, 4096)

# %%
X[189]
# Out:
# array([  7.,  18.,  33., ..., 109., 186.,   2.])

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel='rbf', C=10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7916666666666666

# %%
len(X_test)
# Out:
# 48

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         6
#            1       0.73      0.80      0.76        10
#            2       0.71      0.71      0.71         7
#            3       0.83      0.94      0.88        16
#            4       0.80      0.89      0.84         9
#
#     accuracy                           0.79        48
#    macro avg       0.81      0.73      0.74        48
# weighted avg       0.81      0.79      0.78        48

# %% [markdown]
# # GridSearch

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto', probability=True),
        'params': {
            'svc__C': [1, 10, 100, 1000],
            'svc__kernel': ['rbf', 'linear']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params': {
            'randomforestclassifier__n_estimators': [1, 5, 10]
        }
    },
    'logistic_regression': {
        'model': LogisticRegression(solver='liblinear', multi_class='auto'),
        'params': {
            'logisticregression__C': [1, 5, 10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf = GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores, columns=['model', 'best_score', 'best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.754187
# 1        random_forest    0.584975
# 2  logistic_regression    0.761084
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['logistic_regression'].score(X_test, y_test)
# Out:
# 0.8333333333333334

# %%
pipe_2 = Pipeline([('scaler', StandardScaler()), ('svc', LogisticRegression(C=1,
                                                         fit_intercept=True,
                                                         max_iter=10,
                                                         multi_class='auto',
                                                         solver='lbfgs',
                                                         warm_start=True))])
pipe_2.fit(X_train, y_train)
pipe_2.score(X_test, y_test)
# Out:
# C:\Users\79173\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8125

# %%
pipe_2.score(X_test, y_test)
# Out:
# 0.8125

# %%
best_estimators_2['logistic_regression'] = pipe_2

# %%
best_estimators_2['logistic_regression'].score(X_test, y_test)
# Out:
# 0.8125

# %%
best_clf = best_estimators_2['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 4,  0,  0,  0,  2],
#        [ 0,  8,  0,  2,  0],
#        [ 1,  0,  5,  0,  1],
#        [ 0,  2,  0, 14,  0],
#        [ 0,  0,  1,  0,  8]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize=(10, 7))
sn.heatmap(cm, annot=True)
plt.xlabel('prediction')
plt.ylabel('truth')
# Out:
# Text(95.72222222222221, 0.5, 'truth')

# %%
class_dict
# Out:
# {'chuck_berry': 0,
#  'eminem': 1,
#  'justin_bieber': 2,
#  'madonna': 3,
#  'whitney_houston': 4}

# %% [markdown]
# # SAVE MODEL

# %%
# save the model as a pickle in a file
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\79173\appdata\local\programs\python\python310\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open('class_dictionary.json', 'w') as f:
    f.write(json.dumps(class_dict))
